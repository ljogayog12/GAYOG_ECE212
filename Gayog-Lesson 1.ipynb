# %% [markdown]
# # MODULE 1: Scientific Computing Basics
# ---

# %% [markdown]
# ## LESSON 1: INTRODUCTION TO PYTHON

# %% [markdown]
# ### Introduction
# ---

# %% [markdown]
#    Python is a deciphered, object-arranged, high-level programming language with complex semantics. The plain, easy-to-learn syntax of Python enhances readability and thus decreases software maintenance costs. Python manages modules and packages that promote software precision and reuse of code.                                                                                      The Python translator and the large standard library are available free of charge in the source or paired structure at each major point and can be uninhibitedly disseminated.                                                                                   So, in this lesson, this course pack will teach us how to understand and make a program in Python. Understanding computer programs requires an algorithmic, unthinking justification. In this way, knowledge of computer codes entails a lot of mental recreation of what is actually going to happen, not what you expect to happen. In addition, this includes creative analytical thought, which means the capacity to prepare, to consider arrangements and to articulate them unequivocally and specifically.

# %% [markdown]
# ### Activity
#
# 1.) Why do you think understanding computer programs is relevant in our time today especially in the new normal?
#
# As Steve Jobs once said, "Everybody in this country should learn how to program a computer because it teaches you how to think." Computer programming is a massively adaptable technique that you can use to do stunning tasks that are usually either manual and laborious or literally outlandish. Computer programming makes life easy for us, by coding it produces systematic and creative thinking, and by learning programs it helps us to be persistent. Especially in this new normal stage of life, programming is kind of important to all of us. Since we are confined to doing something outside our premises, we prefer to abuse this by using our digital devices.
#
# 2.) If you were able to learn computer program, what program will you code? Why?
#
# If I could know a computer program, I suppose I'm going to stick to studying python. As it has been said, Python language is not only a high-level programming language, but is also flexible and is currently being taught.
#
# 3.) What would be your pirmary motivation in learning programming?
#
# The main reason will be that this would allow us a lot to consider our profession in the future. Apart from that, this current standard condition may also serve to facilitate the management of operations on computers.

# %% [markdown]
# ### Application: Ask Yourself
#
# 1.) Why do you think Python is the most applicable programming language for scientific computing?
#
# What really is Python? Writing Python code is easy, and the rate of development apart from reading Python code is similarly normal. Over all, Python still offers us tried and tested adaptability. This makes Python's claim one of the most looked for in the wake of accreditation programming. Programming languages have been around for quite a time, and they reliably watch the dispatch of other languages intensely motivating designers. Python is quickly growing to the front line of the most mainstream programming languages in the world, and its remarkable creation has unmistakably emerged on Stock Overflow as opposed to other programming languages.
#
# 2.) If Python can build anything, where do you think Python is not applicable for?
#
# Despite the fact that Python can construct something, there are a few drawbacks as well. Python has a modest speed of execution, which means that it operates as an interpreter, not a compiler. Python runs slower than C, C++, Java and several different languages. Second, it has an immense amount of memory usage, and so it is not fair to use it for improvement under restricted memory constraint.Third, the change in Smartphone and Gaming is not acceptable due to the use of more memory and its modest speed of handling relative to other programming dialects. Finally, it's hard to test, because it's an interpreter-based language, it's hard to run experiments on code written in Python.

# %% [markdown]
# ### Exercises

# %% [markdown]
# #### Exercise 1: Mailing Address (Solved, 9 Lines)

# %% [markdown]
# Create a program that displays your name and complete mailing addresss. The address should be printed in the format that is normally used in the area where you live. You program does not need to ready any input from the user.

# %%
print("Full Name: Lance Joseph Ortiz Gayog")
print("Address: Cabardo Apartment, San Vicente")
print ("Buhangin, Davao City")
print ("Contact Number: 09266620422")
print ("Email Address: ljogayog@usep.edu.ph")
print ("Email Address: lancegayog@gmail.com")
print("8505")
print ("Mindanao")
print ("Philippines")

# %% [markdown]
# Full Name: Lance Joseph O. Gayog<div>
# Address: Cabardo Apartment, San Vicente<div>
# Buhangin, Davao City<div>
# Contact Number: 09266620422<div>
# Email Address: ljogayog@usep.edu.ph<div>
# Email Address: lancegayog@gmail.com<div>
# 8505<div>
# Mindanao<div>
# Philippines

# %% [markdown]
# #### Exercise 2: Area of a Room (Solved, 13 Lines)

# %% [markdown]
# Write a program that asks the user to enter the width and length of a room. Once these values have been read, your program should compute and display the area of the room. The length and the width will be entered as floating-point numbers. Include units in your prompt and output message; either feet or meters, depending on which unit you are more comfortable working with.

# %%
#compute the area of the room

#read the dimensions from the user
length = float(input("Enter the length of the room in meters:"))
width = float(input("Enter the width of the room in meters:"))

#compute the area of the room
area = length * width

#display the results
print("The area of the room is", area, "squared meters")

# %% [markdown]
# Enter the length of the room in meters:4<div>
# Enter the width of the room in meters:5<div>
# The area of the room is 20.0 squared meters<div>

# %% [markdown]
# ####  Exercise 3: Arithmetic (Solved, 22 Lines)

# %% [markdown]
# Create a program that reads two integers, a and b, from the user. Your program should compute and display:
#
# •The sum of a and b
#
# •The difference when b is subtracted from a
#
# •The product of a and b
#
# •The quotient when a is divided by b
#
# •The remainder when a is divided by b
#
# •The result of log10 a
#
# •The result of ab
#
# Hint: You will probably find the log10 function in the math module helpful for computing the second last item in the list.

# %%
# four integers
a = float (input("Value of a: "))
b =  float (input("Value of b:  "))
 
sum = a + b
print ("Sum of a and b: ", sum)

difference = a - b
print ("b subtracted to a: ", difference)

product = a*b
print ("Product of a and b: ", product)

quotient = a/b
print ("quotient of a and b: ",quotient)

remainder = a%b
print ("Remainder of a divided by b: ", remainder)

import math
log = math.log10(a)
print ("log10a: ", log)

import math
log = math.log10(a*b)
print ("log10a*b : ", log)

# %% [markdown]
# Value of a: 3<div>
# Value of b:  4<div>
# Sum of a and b:  7.0<div>
# b subtracted to a:  -1.0<div>
# Product of a and b:  12.0<div>
# quotient of a and b:  0.75<div>
# Remainder of a divided by b:  3.0<div>
# log10a:  0.47712125471966244<div>
# log10a*b :  1.0791812460476249<div>

# %% [markdown]
# #### Exercise 4: Area and Volume (15 Lines)

# %% [markdown]
# Write a program that begins by reading a radius, r, from the user. The program will continue by computing and displaying the area of a circle with radius r and the volume of a sphere with radius r. Use the pi constant in the math module in your calculations.

# %%
#area of a circle, and the volume of a sphere by just defining radius r.

import math
r = float(input("Enter the radius in meter: "))

area = math.pi * r * r
volume = (4/3) * math.pi * r * r * r

print("The area of a circle is:",area,"squared meters.")
print("The volume of a sphere is:",volume,"cubic meters.")

# %% [markdown]
# Enter the radius in meter: 3<div>
# The area of a circle is: 28.274333882308138 squared meters.<div>
# The volume of a sphere is: 113.09733552923255 cubic meters.<div>
